# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (374 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# ...

# %%
# !dos2unix /content/gdrive/Shareddrives/Share/dataset_final/RGB/train.txt
# !dos2unix /content/gdrive/Shareddrives/Share/dataset_final/RGB/test.txt
# !dos2unix /content/gdrive/Shareddrives/Share/dataset_final/RGB/classes.txt
# !dos2unix /content/gdrive/Shareddrives/Share/dataset_final/RGB/label_data.data
# !dos2unix /content/gdrive/Shareddrives/Share/dataset_final/RGB/classes.names
# !dos2unix /content/gdrive/Shareddrives/Share/darknet/cfg/RGB_final.cfg
# Out:
# dos2unix: converting file /content/gdrive/Shareddrives/Share/dataset_combine_2color/test_final_2/RGB/train.txt to Unix format...
# dos2unix: converting file /content/gdrive/Shareddrives/Share/dataset_combine_2color/test_final_2/RGB/test.txt to Unix format...
# dos2unix: converting file /content/gdrive/Shareddrives/Share/dataset_combine_2color/test_final_2/RGB/classes.txt to Unix format...
# dos2unix: converting file /content/gdrive/Shareddrives/Share/dataset_combine_2color/test_final_2/RGB/label_data.data to Unix format...
# dos2unix: converting file /content/gdrive/Shareddrives/Share/dataset_combine_2color/test_final_2/RGB/classes.names to Unix format...
# dos2unix: converting file /content/gdrive/Shareddrives/Share/darknet/cfg/rgb_combine_final.cfg to Unix format...

# %%
# %cd /content/gdrive/Shareddrives/Share/darknet3
# !ls
# Out:
# /content/gdrive/Shareddrives/Share/darknet3
# backup	  data		libdarknet.so  LICENSE.gpl   Makefile	results
# bad.list  examples	LICENSE        LICENSE.meta  obj	scripts
# cfg	  include	LICENSE.fuck   LICENSE.mit   python	src
# darknet   libdarknet.a	LICENSE.gen    LICENSE.v1    README.md

# %%
# !pwd
# Out:
# /content/gdrive/Shareddrives/Share/darknet

# %%
# !sudo apt install libopencv-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !make
# !chmod +x ./darknet
# Out:
# make: Nothing to be done for 'all'.

# %%
# !./darknet detector train /content/gdrive/Shareddrives/Share/dataset_final/RGB/label_data.data /content/gdrive/Shareddrives/Share/darknet/cfg/RGB_final.cfg
# Out:
# Streaming output truncated to the last 5000 lines.
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.963353, Class: 0.999743, Obj: 0.999828, No Obj: 0.000936, .5R: 1.000000, .75R: 1.000000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 82 Avg IOU: 0.942679, Class: 0.999702, Obj: 0.999648, No Obj: 0.000937, .5R: 1.000000, .75R: 1.000000,  count: 4
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000002, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# ...

# %%
# %cd /content/gdrive/Shareddrives/Share/dataset_rev02/RGBD/
# !ls
# Out:
# /content/gdrive/Shareddrives/Share/dataset_rev02/RGBD
# classes.names		fuse_image_8bit221.txt	fuse_image_8bit345.png
# classes.txt		fuse_image_8bit222.png	fuse_image_8bit345.txt
# fuse_image_8bit0.png	fuse_image_8bit222.txt	fuse_image_8bit346.png
# fuse_image_8bit0.txt	fuse_image_8bit223.png	fuse_image_8bit346.txt
# fuse_image_8bit100.png	fuse_image_8bit223.txt	fuse_image_8bit347.png
# fuse_image_8bit100.txt	fuse_image_8bit224.png	fuse_image_8bit347.txt
# fuse_image_8bit101.png	fuse_image_8bit224.txt	fuse_image_8bit348.png
# fuse_image_8bit101.txt	fuse_image_8bit225.png	fuse_image_8bit348.txt
# fuse_image_8bit102.png	fuse_image_8bit225.txt	fuse_image_8bit349.png
# fuse_image_8bit102.txt	fuse_image_8bit226.png	fuse_image_8bit349.txt
# fuse_image_8bit103.png	fuse_image_8bit226.txt	fuse_image_8bit34.png
# fuse_image_8bit103.txt	fuse_image_8bit227.png	fuse_image_8bit34.txt
# fuse_image_8bit104.png	fuse_image_8bit227.txt	fuse_image_8bit350.png
# ...

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# !./darknet partial cfg/yolov3-tiny.cfg yolov3-tiny.weights yolov3-tiny.conv.15 15
# Out:
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16  0.150 BFLOPs
#     1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16
#     2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32  0.399 BFLOPs
#     3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32
#     4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64  0.399 BFLOPs
#     5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64
#     6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128  0.399 BFLOPs
#     7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128
#     8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256  0.399 BFLOPs
#     9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256
#    10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512  0.399 BFLOPs
# ...

# %%
# !./darknet detector train cfg/traffic_data.data cfg/yolov3-tiny.cfg yolov3-tiny.conv.15 -dont_show
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# Region 16 Avg IOU: 0.860249, Class: 0.999757, Obj: 0.997626, No Obj: 0.004011, .5R: 1.000000, .75R: 1.000000,  count: 4
# Region 23 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 16 Avg IOU: 0.905189, Class: 0.997643, Obj: 0.998790, No Obj: 0.003994, .5R: 1.000000, .75R: 1.000000,  count: 4
# Region 23 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 16 Avg IOU: 0.855447, Class: 0.975654, Obj: 0.932175, No Obj: 0.003180, .5R: 1.000000, .75R: 1.000000,  count: 4
# Region 23 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# Region 16 Avg IOU: 0.882389, Class: 0.998234, Obj: 0.997100, No Obj: 0.003452, .5R: 1.000000, .75R: 1.000000,  count: 4
# Region 23 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.000001, .5R: -nan, .75R: -nan,  count: 0
# ...
